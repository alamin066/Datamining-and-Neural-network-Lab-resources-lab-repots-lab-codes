# %%
import pandas as pd

# %%
dataframe = pd.DataFrame({
    'id': [1, 2, 2, 3, 4, 4, 4],
    'name': ['Alice', 'Bob', 'Bob', 'Charlie', 'David', 'David', 'David'],
    'email': [
        'a@example.com',
        'b@example.com',
        'b@example.com',
        'c@example.com',
        'd@example.com',
        'd@example.com',
        'd@example.com'
    ]
})

# %%
dataframe
# Out:
#    id     name          email
# 0   1    Alice  a@example.com
# 1   2      Bob  b@example.com
# 2   2      Bob  b@example.com
# 3   3  Charlie  c@example.com
# 4   4    David  d@example.com
# 5   4    David  d@example.com
# 6   4    David  d@example.com

# %%
clean_data = dataframe.drop_duplicates()

# %%
clean_data
# Out:
#    id     name          email
# 0   1    Alice  a@example.com
# 1   2      Bob  b@example.com
# 3   3  Charlie  c@example.com
# 4   4    David  d@example.com

# %%
dataframe = pd.DataFrame({
    'id': [1, 2, 2, 3, 4, 4, 4],
    'name': ['Alice', 'Bob', 'Bob', 'Charlie', 'David', 'David', 'David'],
    'email': [
        'a@example.com',
        'b@example.com',
        'b@example.com',
        'c@example.com',
        'd@example.com',
        'd@example.com',
        'd@example.com'
    ],
    'email1': [
        'a@example.com',
        'b@example.com',
        'b@example.com',
        'c@example.com',
        'd@example.com',
        'd@example.com',
        'd@example.com'
    ],
})

# %%
dataframe
# Out:
#    id     name          email         email1
# 0   1    Alice  a@example.com  a@example.com
# 1   2      Bob  b@example.com  b@example.com
# 2   2      Bob  b@example.com  b@example.com
# 3   3  Charlie  c@example.com  c@example.com
# 4   4    David  d@example.com  d@example.com
# 5   4    David  d@example.com  d@example.com
# 6   4    David  d@example.com  d@example.com

# %%
duplicate_columns = []

# %%
for i in dataframe.columns:
    for j in dataframe.columns:
        if i!=j and dataframe[i].equals(dataframe[j]):
            duplicate_columns.append((i,j))

# %%
duplicate_columns
# Out:
# [('email', 'email1'), ('email1', 'email')]

# %%
dataframe.drop(columns=['email1'])
# Out:
#    id     name          email
# 0   1    Alice  a@example.com
# 1   2      Bob  b@example.com
# 2   2      Bob  b@example.com
# 3   3  Charlie  c@example.com
# 4   4    David  d@example.com
# 5   4    David  d@example.com
# 6   4    David  d@example.com

# %%
import pandas as pd
import numpy as np

# Create a sample DataFrame with an outlier
data = {
    'id': [1, 2, 3, 4, 5, 6],
    'age': [25, 27, 29, 31, 120, 28],   # 120 is an outlier
    'salary': [3000, 3200, 3500, 4000, 5000, 100000]  # 100000 is an outlier
}

df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)
# Out:
# Original DataFrame:
#    id  age  salary
# 0   1   25    3000
# 1   2   27    3200
# 2   3   29    3500
# 3   4   31    4000
# 4   5  120    5000
# 5   6   28  100000

# %%
outlier_info = {}
for i in ['age', 'salary']:
    q1 = df[i].quantile(0.25)
    q3 = df[i].quantile(0.75)

    IQR = q3-q1
    lower_bound = q1- 1.5*IQR
    upper_bound = q3 + 1.5*IQR

    x = df[i]< lower_bound | df[i]>upper_bound
    outlier_info[i] = df[x]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:362, in na_logical_op(x, y, op)
#     353 try:
#     354     # For exposition, write:
#     355     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     360     # Then Cases where this goes through without raising include:
#     361     #  (xint or xbool) and (yint or bool)
# --> 362     result = op(x, y)
#     363 except TypeError:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\roperator.py:58, in ror_(left, right)
#      57 def ror_(left, right):
# ---> 58     return operator.or_(right, left)
#
# TypeError: ufunc 'bitwise_or' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
outlier_info

# %%
import pandas as pd

data = {
    'department': ['Sales', 'Sales', 'HR', 'HR', 'IT', 'IT', 'Sales'],
    'employee': ['Alice', 'Bob', 'Charlie', 'David', 'Eva', 'Frank', 'Grace'],
    'salary': [5000, 6000, 4500, 4700, 7000, 7200, 5200],
    'bonus': [500, 600, 300, 400, 700, 800, 550]
}

# %%
dataframe = pd.DataFrame(data)

# %%
dataframe

# %%
group = dataframe.groupby('department')

# %%
group.agg(
    {'salary':'sum',
     'bonus':'sum'
    }
)

# %%
dataframe = pd.DataFrame({
    'Age':[10,20,30],
    "Gender":["M","F","M"],
    "Graduation":["UG","PG","P.hd"],
    "Target":["Yes","Yes","No"]}
)

# %%
dataframe
# Out:
#    Age Gender Graduation Target
# 0   10      M         UG    Yes
# 1   20      F         PG    Yes
# 2   30      M       P.hd     No

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder(categories=[["P.hd","PG","UG"]])

# %%
oe.fit_transform(dataframe[["Graduation"]])
# Out:
# array([[2.],
#        [1.],
#        [0.]])

# %%
dataframe
# Out:
#    Age Gender Graduation Target
# 0   10      M         UG    Yes
# 1   20      F         PG    Yes
# 2   30      M       P.hd     No

# %%
dataframe["Graduation"]= oe.fit_transform(dataframe[["Graduation"]])

# %%
dataframe
# Out:
#    Age Gender  Graduation Target
# 0   10      M         2.0    Yes
# 1   20      F         1.0    Yes
# 2   30      M         0.0     No

# %%
df2 = pd.get_dummies(dataframe["Gender"])

# %%
x = dataframe.drop(columns="Gender")

# %%
pd.concat([x,df2],axis=1)
# Out:
#    Age  Graduation Target      F      M
# 0   10         2.0    Yes  False   True
# 1   20         1.0    Yes   True  False
# 2   30         0.0     No  False   True

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
le.fit_transform(dataframe["Target"])
# Out:
# array([1, 1, 0])

# %%
dataframe["Target"]= le.fit_transform(dataframe["Target"])

# %%
dataframe
# Out:
#    Age Gender  Graduation  Target
# 0   10      M         2.0       1
# 1   20      F         1.0       1
# 2   30      M         0.0       0
